# %% [markdown]
# <a href="https://www.kaggle.com/code/pawankumaragrawal/car-insurance-fraud-claim?scriptVersionId=112012469" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %matplotlib inline
import seaborn as sns
import sklearn

# %%
df_train = pd.read_csv('/kaggle/input/vidya-car-insurance-fraud-claim/train_qWM28Yl.csv')
df_train.head(3)
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID00001       0.515874        0.05             0.644231           C1
# 1   ID00002       0.672619        0.02             0.375000           C2
# 2   ID00003       0.841110        0.02             0.384615           C3
#
#    population_density  make segment model fuel_type  ... is_brake_assist  \
# 0                4990     1       A    M1       CNG  ...              No
# 1               27003     1       A    M1       CNG  ...              No
# 2                4076     1       A    M1       CNG  ...              No
#
#   is_power_door_locks is_central_locking  is_power_steering  \
# 0                  No                 No                Yes
# 1                  No                 No                Yes
# 2                  No                 No                Yes
#
#   is_driver_seat_height_adjustable is_day_night_rear_view_mirror is_ecw  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58592 entries, 0 to 58591
# Data columns (total 44 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   policy_id                         58592 non-null  object
#  1   policy_tenure                     58592 non-null  float64
#  2   age_of_car                        58592 non-null  float64
#  3   age_of_policyholder               58592 non-null  float64
#  4   area_cluster                      58592 non-null  object
#  5   population_density                58592 non-null  int64
#  6   make                              58592 non-null  int64
#  7   segment                           58592 non-null  object
#  8   model                             58592 non-null  object
#  9   fuel_type                         58592 non-null  object
#  10  max_torque                        58592 non-null  object
# ...

# %%
df_train['is_claim'].value_counts()
# Out:
# 0    54844
# 1     3748
# Name: is_claim, dtype: int64

# %%
categorical_features = [cols for cols in df_train if df_train[cols].dtype == 'object']
categorical_features
# Out:
# ['policy_id',
#  'area_cluster',
#  'segment',
#  'model',
#  'fuel_type',
#  'max_torque',
#  'max_power',
#  'engine_type',
#  'is_esc',
#  'is_adjustable_steering',
#  'is_tpms',
#  'is_parking_sensors',
#  'is_parking_camera',
#  'rear_brakes_type',
#  'transmission_type',
#  'steering_type',
#  'is_front_fog_lights',
#  'is_rear_window_wiper',
#  'is_rear_window_washer',
#  'is_rear_window_defogger',
#  'is_brake_assist',
#  'is_power_door_locks',
#  'is_central_locking',
#  'is_power_steering',
#  'is_driver_seat_height_adjustable',
#  'is_day_night_rear_view_mirror',
#  'is_ecw',
#  'is_speed_alert']

# %%
df_train_new1 = pd.get_dummies(data=df_train, columns=[
'area_cluster',
 'segment',
 'model',
 'fuel_type',
 'max_torque',
 'max_power',
 'engine_type',
 'is_esc',
 'is_adjustable_steering',
 'is_tpms',
 'is_parking_sensors',
 'is_parking_camera',
 'rear_brakes_type',
 'transmission_type',
 'steering_type',
 'is_front_fog_lights',
 'is_rear_window_wiper',
 'is_rear_window_washer',
 'is_rear_window_defogger',
 'is_brake_assist',
 'is_power_door_locks',
 'is_central_locking',
 'is_power_steering',
 'is_driver_seat_height_adjustable',
 'is_day_night_rear_view_mirror',
 'is_ecw',
 'is_speed_alert'
], drop_first=True)
df_train_new1.head(3)
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder  \
# 0   ID00001       0.515874        0.05             0.644231
# 1   ID00002       0.672619        0.02             0.375000
# 2   ID00003       0.841110        0.02             0.384615
#
#    population_density  make  airbags  displacement  cylinder  gear_box  ...  \
# 0                4990     1        2           796         3         5  ...
# 1               27003     1        2           796         3         5  ...
# 2                4076     1        2           796         3         5  ...
#
#    is_rear_window_washer_Yes  is_rear_window_defogger_Yes  \
# 0                          0                            0
# 1                          0                            0
# 2                          0                            0
#
#    is_brake_assist_Yes  is_power_door_locks_Yes  is_central_locking_Yes  \
# 0                    0                        0                       0
# ...

# %%
df_train_new1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58592 entries, 0 to 58591
# Columns: 102 entries, policy_id to is_speed_alert_Yes
# dtypes: float64(4), int64(12), object(1), uint8(85)
# memory usage: 12.3+ MB

# %%
df_train_new1.drop(columns = 'policy_id', axis = 1, inplace = True)
df_train_new1.sample(3)
# Out:
#        policy_tenure  age_of_car  age_of_policyholder  population_density  \
# 7857        0.485660         0.1             0.519231               27742
# 13616       0.140589         0.0             0.403846                4076
# 55928       1.015564         0.1             0.634615               27003
#
#        make  airbags  displacement  cylinder  gear_box  turning_radius  ...  \
# 7857      1        2          1197         4         5             4.8  ...
# 13616     1        2           796         3         5             4.6  ...
# 55928     1        2          1197         4         5             4.8  ...
#
#        is_rear_window_washer_Yes  is_rear_window_defogger_Yes  \
# 7857                           0                            0
# 13616                          0                            0
# 55928                          0                            0
#
#        is_brake_assist_Yes  is_power_door_locks_Yes  is_central_locking_Yes  \
# ...

# %%
from sklearn.utils import resample
#create two different dataframe of majority and minority class 
df_majority = df_train_new1[(df_train_new1['is_claim']==0)] 
df_minority = df_train_new1[(df_train_new1['is_claim']==1)] 
# upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,    # sample with replacement
                                 n_samples= 54844, # to match majority class
                                 random_state=42)  # reproducible results
# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_minority_upsampled, df_majority])
df_upsampled.head(3)
# Out:
#        policy_tenure  age_of_car  age_of_policyholder  population_density  \
# 49225       1.036669        0.01             0.413462               27742
# 54406       0.559076        0.07             0.490385               21622
# 13153       0.998662        0.13             0.490385                5410
#
#        make  airbags  displacement  cylinder  gear_box  turning_radius  ...  \
# 49225     1        2           998         3         5             4.7  ...
# 54406     3        6          1493         4         6             5.2  ...
# 13153     1        2          1197         4         5             4.8  ...
#
#        is_rear_window_washer_Yes  is_rear_window_defogger_Yes  \
# 49225                          0                            0
# 54406                          1                            1
# 13153                          0                            0
#
#        is_brake_assist_Yes  is_power_door_locks_Yes  is_central_locking_Yes  \
# ...

# %%
df_upsampled['is_claim'].value_counts()
# Out:
# 1    54844
# 0    54844
# Name: is_claim, dtype: int64

# %%
X = df_upsampled.drop(columns = 'is_claim', axis = 1)
y = df_upsampled['is_claim']

# %%
# train_test_split
from sklearn.model_selection import train_test_split
(X_train, X_val, y_train, y_val) = train_test_split(X, y, test_size = 0.2)

# %%
# importing random forest classifier from ensemble module
from sklearn.ensemble import RandomForestClassifier

# creating a RF classifier
rfc = RandomForestClassifier(n_estimators = 100) 
 
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
rfc.fit(X_train, y_train)

# performing predictions on the validation dataset
y_pred_val = rfc.predict(X_val)

# %%
# Constructing the confusion matrix.
from sklearn.metrics import confusion_matrix
confusion_matrix(y_val, y_pred_val)
# Out:
# array([[10564,   366],
#        [    4, 11004]])

# %%
# To compute the F1 score, simply call the f1_score() function:
from sklearn.metrics import f1_score
f1_score(y_val, y_pred_val)
# Out:
# 0.9834659040128697

# %%
df_test = pd.read_csv('/kaggle/input/vidya-car-insurance-fraud-claim/test_zo1G9sv.csv')
df_test.head(3)
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID58593       0.341732        0.00             0.586538           C3
# 1   ID58594       0.307241        0.13             0.442308           C8
# 2   ID58595       0.327924        0.12             0.451923           C8
#
#    population_density  make segment model fuel_type  ...  \
# 0                4076     1       A    M1       CNG  ...
# 1                8794     1      B2    M6    Petrol  ...
# 2                8794     2       A    M3    Petrol  ...
#
#   is_rear_window_defogger is_brake_assist is_power_door_locks  \
# 0                      No              No                  No
# 1                      No             Yes                 Yes
# 2                      No              No                 Yes
#
#    is_central_locking is_power_steering is_driver_seat_height_adjustable  \
# 0                  No               Yes                               No
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39063 entries, 0 to 39062
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   policy_id                         39063 non-null  object
#  1   policy_tenure                     39063 non-null  float64
#  2   age_of_car                        39063 non-null  float64
#  3   age_of_policyholder               39063 non-null  float64
#  4   area_cluster                      39063 non-null  object
#  5   population_density                39063 non-null  int64
#  6   make                              39063 non-null  int64
#  7   segment                           39063 non-null  object
#  8   model                             39063 non-null  object
#  9   fuel_type                         39063 non-null  object
#  10  max_torque                        39063 non-null  object
# ...

# %%
df_test_new1 = pd.get_dummies(data=df_test, columns=[
'area_cluster',
 'segment',
 'model',
 'fuel_type',
 'max_torque',
 'max_power',
 'engine_type',
 'is_esc',
 'is_adjustable_steering',
 'is_tpms',
 'is_parking_sensors',
 'is_parking_camera',
 'rear_brakes_type',
 'transmission_type',
 'steering_type',
 'is_front_fog_lights',
 'is_rear_window_wiper',
 'is_rear_window_washer',
 'is_rear_window_defogger',
 'is_brake_assist',
 'is_power_door_locks',
 'is_central_locking',
 'is_power_steering',
 'is_driver_seat_height_adjustable',
 'is_day_night_rear_view_mirror',
 'is_ecw',
 'is_speed_alert'
], drop_first=True)
df_test_new1.head(3)
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder  \
# 0   ID58593       0.341732        0.00             0.586538
# 1   ID58594       0.307241        0.13             0.442308
# 2   ID58595       0.327924        0.12             0.451923
#
#    population_density  make  airbags  displacement  cylinder  gear_box  ...  \
# 0                4076     1        2           796         3         5  ...
# 1                8794     1        2          1197         4         5  ...
# 2                8794     2        2           999         3         5  ...
#
#    is_rear_window_washer_Yes  is_rear_window_defogger_Yes  \
# 0                          0                            0
# 1                          0                            0
# 2                          0                            0
#
#    is_brake_assist_Yes  is_power_door_locks_Yes  is_central_locking_Yes  \
# 0                    0                        0                       0
# ...

# %%
df_test_new2 = df_test_new1.drop(columns = 'policy_id', axis = 1)
df_test_new2.head(3)
# Out:
#    policy_tenure  age_of_car  age_of_policyholder  population_density  make  \
# 0       0.341732        0.00             0.586538                4076     1
# 1       0.307241        0.13             0.442308                8794     1
# 2       0.327924        0.12             0.451923                8794     2
#
#    airbags  displacement  cylinder  gear_box  turning_radius  ...  \
# 0        2           796         3         5             4.6  ...
# 1        2          1197         4         5             4.8  ...
# 2        2           999         3         5             5.0  ...
#
#    is_rear_window_washer_Yes  is_rear_window_defogger_Yes  \
# 0                          0                            0
# 1                          0                            0
# 2                          0                            0
#
#    is_brake_assist_Yes  is_power_door_locks_Yes  is_central_locking_Yes  \
# 0                    0                        0                       0
# ...

# %%
# performing predictions on the test dataset
X_test=df_test_new2.to_numpy()
y_pred_test = rfc.predict(X_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
y_pred_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df_is_claim = pd.DataFrame(y_pred_test, columns =['is_claim'])

# %%
df_is_claim.head(3)
# Out:
#    is_claim
# 0         0
# 1         0
# 2         0

# %%
df_concatenated = pd.concat([df_test_new1, df_is_claim], axis=1)
df_concatenated.head(3)
# Out:
#   policy_id  policy_tenure  age_of_car  age_of_policyholder  \
# 0   ID58593       0.341732        0.00             0.586538
# 1   ID58594       0.307241        0.13             0.442308
# 2   ID58595       0.327924        0.12             0.451923
#
#    population_density  make  airbags  displacement  cylinder  gear_box  ...  \
# 0                4076     1        2           796         3         5  ...
# 1                8794     1        2          1197         4         5  ...
# 2                8794     2        2           999         3         5  ...
#
#    is_rear_window_defogger_Yes  is_brake_assist_Yes  is_power_door_locks_Yes  \
# 0                            0                    0                        0
# 1                            0                    1                        1
# 2                            0                    0                        1
#
#    is_central_locking_Yes  is_power_steering_Yes  \
# 0                       0                      1
# ...

# %%
df_final =df_concatenated[['policy_id', 'is_claim']]
df_final.head(10)
# Out:
#   policy_id  is_claim
# 0   ID58593         0
# 1   ID58594         0
# 2   ID58595         0
# 3   ID58596         0
# 4   ID58597         0
# 5   ID58598         0
# 6   ID58599         0
# 7   ID58600         0
# 8   ID58601         0
# 9   ID58602         0

# %%
df_final.to_csv('result.csv')
